# %%
from PIL import Image
import requests
import numpy as np

# %%
from transformers import AutoImageProcessor, AutoModel

# %%
device = 'cuda'

# %%
processor = AutoImageProcessor.from_pretrained('facebook/dinov2-small')
model = AutoModel.from_pretrained('facebook/dinov2-small').to(device)
# Out:
# preprocessor_config.json:   0%|          | 0.00/436 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/547 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/88.2M [00:00<?, ?B/s]

# %%
url = 'http://images.cocodataset.org/val2017/000000039769.jpg'
image = Image.open(requests.get(url, stream=True).raw)

# %%
inputs = processor(images=image, return_tensors="pt").to(device)
outputs = model(**inputs)
last_hidden_states = outputs.last_hidden_state.mean(dim=1)

# %%
last_hidden_states.device.type == 'cuda'
# Out:
# True

# %%
type(last_hidden_states)
# Out:
# torch.Tensor

# %%
last_hidden_states.cpu().detach().numpy().shape
# Out:
# (1, 384)

# %%
from imgbeddings import imgbeddings
ibed = imgbeddings()
# Out:
# /home/moonlab/sattwik/vision-language-mapping/ragseg/.venv/lib/python3.12/site-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'cached_download' (from 'huggingface_hub.file_download') is deprecated and will be removed from version '0.26'. Use `hf_hub_download` instead.
#   warnings.warn(warning_message, FutureWarning)
# /home/moonlab/sattwik/vision-language-mapping/ragseg/.venv/lib/python3.12/site-packages/huggingface_hub/file_download.py:672: FutureWarning: 'cached_download' is the legacy way to download files from the HF hub, please consider upgrading to 'hf_hub_download'
#   warnings.warn(
# /home/moonlab/sattwik/vision-language-mapping/ragseg/.venv/lib/python3.12/site-packages/transformers/tokenization_utils_base.py:1617: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be deprecated in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# /home/moonlab/sattwik/vision-language-mapping/ragseg/.venv/lib/python3.12/site-packages/transformers/models/clip/processing_clip.py:149: FutureWarning: `feature_extractor` is deprecated and will be removed in v5. Use `image_processor` instead.
#   warnings.warn(

# %%
ibed.to_embeddings(image).shape
# Out:
# (1, 768)
